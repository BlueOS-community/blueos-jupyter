# %% [markdown]
# # 🐍 Navigator and Webscoket for Python! 🚀
#
# In this interactive guide, you'll learn how to use Navigator Assistant.
#
# Navigator Assistant is webserver that handle navigator-rs library and allows users to use it through web based applications.
#
# ## What You'll Learn
#
# With this guide, you will learn how to:
#
# 1. 🌟 Initiate your Navigator-Assistant
# 2. 🎉 Use websocket to connect to assistant's service
# 3. 🌡️ Plot live data
# 4. ⚙️ Send commands
#
# Click bellow to start it!

# %% [markdown]
# ## 1. Initiate your Navigator-Assistant
#
# The easiest way to start using Navigator-Assistant, is through itself BlueOS's Extension.
#
# You can find it on:
# http://blueos.local/tools/extensions-manager
#
# Or you can download the navigator-assistant binary and run locally.

# %% [markdown]
# ## 2. Use websocket to connect to assistant's service
#
# Now with this first example you will be abble to connect to navigator-assistant and receive it's first websocket message.
#
# Please install the bellow package to use websockets.

# %%
pip install --user websocket-client

# %% [markdown]
# Now you can run and check your first websocket message from Navigator-Assistant!

# %%
import websocket

def on_message(ws, message):
    print(message)
    wsapp.close()
def on_error(wsapp, err):
    print("Got a an error: ", err)

# Change ip adress and port to yours Navigator Assitant Extension OR self running Navigator service
wsapp = websocket.WebSocketApp("ws://192.168.15.192:32773/ws",

on_message = on_message,
on_error=on_error)
wsapp.run_forever()
# Out:
# {
#   "id": "BlueOS_ID_0123",
#   "input": [
#     {
#       "type": "Temperature",
#       "unit": "C",
#       "value": 35.86000061035156
#     },
#     {
#       "type": "Pressure",
#       "unit": "kPa",
#       "value": 101.49320983886719
#     },
#     {
#       "type": "Accelerometer",
#       "unit": "m/s2",
#       "value": [
#         0.047287169843912125,
#         -0.09397576749324799,
#         1.2354521751403809
#       ]
#     },
#     {
#       "type": "Gyroscope",
#       "unit": "rad/s",
#       "value": [
#         0.0067910607904195786,
#         -0.004926848225295544,
#         0.12956279516220093
#       ]
#     },
#     {
#       "type": "Magnetometer",
#       "unit": "uT",
#       "value": [
#         -18.30000114440918,
#         0.9000000357627869,
#         26.250001907348633
#       ]
#     },
#     {
#       "type": "Adc",
#       "unit": "V",
#       "value": [
#         0.03687500208616257,
#         0.03987500071525574,
#         0.04000000283122063,
#         0.04012500122189522
#       ]
#     }
#   ],
#   "model": "Navigator_v4",
#   "timestamp": "2023-10-13 00:26:10.883641961 UTC"
# }
# False

# %% [markdown]
# ## 3. Plot live data
#
# Now with this next example you will be abble to plot live data.
# The follow example is like the Navigator, but we are updating the temperature values as we receive websocket broadcast messages.
#
# Please change the stop_on_max value if you want it to continue after max value.

# %%
import websocket
import json
import plotly.graph_objs as go
from IPython.display import display, clear_output

# Initialize empty lists to store the data for the graph
max_data_points = 10
timestamps = []
temperatures = []

# Change this to have 
stop_on_max= True

# WebSocket message handler
def on_message(ws, message):
    data = json.loads(message)
    if 'input' in data and data['input']:
        for entry in data['input']:
            if entry['type'] == 'Temperature':
                
                timestamps.append(data['timestamp'])
                temperatures.append(entry['value'])

                if len(timestamps) > max_data_points:
                    timestamps.pop(0)
                    temperatures.pop(0)
                    if stop_on_max : ws.close()

                # Create a Plotly figure
                figure = go.Figure()
                
                # Set layout options
                figure.update_layout(
                    title='Real-time Temperature Graph',
                    xaxis_title='Timestamp',
                    yaxis_title='Temperature (°C)'
                )

                figure.add_trace(go.Scatter(x=timestamps, y=temperatures, mode='lines+markers'))
                
                # Clear the output to update the graph in the Jupyter Notebook
                clear_output(wait=True)
                display(figure)

# WebSocket connection
ws = websocket.WebSocketApp("ws://192.168.15.192:32773/ws",
                            on_message=on_message)

# Start WebSocket connection
ws.run_forever()
# Out:
# False

# %% [markdown]
# ## 4. Send commands
#
# Now this example use a different aproach to handle the websocket connection.
#
# Notice that we used a regex filter, the websocket connection allows this.
#
# So, websocket will broadcast only messages containing "output" on it's body.

# %%
from websocket import create_connection
import time

# Change the IP address and port to your WebSocket server
ws = create_connection("ws://192.168.15.192:32773/ws?filter=output")

# Send a message to the WebSocket server
message_to_send = "/output/userled/led1/true"
ws.send(message_to_send)

print("Every webscoket request receive this message:\n")
print(ws.recv())
print("\nFollowed by the broadcasted request:\n")
print(ws.recv())


print("\nNow it will change the userled states for 1 minute.")

# LED names and true/false values to iterate through
leds = ["led1", "led2", "led3"]
states = [True, False]

# Start time
start_time = time.time()

# Run for 1 minute (60 seconds)
while time.time() - start_time < 60:
    # Iterate through LED names and states
    for led in leds:
        for state in states:
            message_to_send = f"/output/userled/{led}/{str(state).lower()}"
            ws.send(message_to_send)
            time.sleep(0.5)  #
        
ws.close()
# Out:
# Every webscoket request receive this message:
#
# "Ok: Command received"
#
# Followed by the broadcasted request:
#
# {
#   "id": "BlueOS_ID_0123",
#   "model": "Navigator_v4",
#   "output": [
#     {
#       "UserLED": {
#         "channel": [
#           "Led1"
#         ],
#         "value": [
#           true
#         ]
#       }
#     }
#   ],
#   "timestamp": "2023-10-13 00:26:23.250589753 UTC"
# }
#
# Now it will change the userled states for 1 minute.
